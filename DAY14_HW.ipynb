# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1)

# %%
#  模擬附相關資料之相關係數
x=np.random.randint(0,70,1000)
y=1000-x+np.random.normal(0,5,1000)
#  correlation coefficience
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.97573642],
#        [-0.97573642,  1.        ]])

# %%
# disttibution of x,y
plt.scatter(x,y)
