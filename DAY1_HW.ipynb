# %%
import numpy as np
import matplotlib.pyplot as plt

# 定義方差函數
def mean_absolute_error(y,yp):
# y:實際data
# yp: 預測值 
    mae=MAE=sum(abs(y-yp))/len(y)
    return mae

# 定義方均根函數

def mean_squared_error(y,yp):
    mse=MSE=sum((y-yp)**2)/len(y)
    return mse

w=3
b=5
x_lin=np.linspace(0,100,101)

# 從random中的Gaussian dist.取樣101個數值
y=(x_lin+np.random.randn(101)*5)*w+b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)

y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()


# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" %(MSE))
print("The Mean absolute error is %.3f" %(MAE))
# Out:
# The Mean squared error is 212.238
# The Mean absolute error is 11.490

# %%
#HW2--Titanic - Machine Learning from Disaster
1. 以鐵達尼號事件生還者資料為借鏡，期望藉由分析種種資料間的關係，預測乘客之生存率
2. 此競賽由kaggle舉辦，資料由kaggle提供
3. 資料型態有數值型、文字型、物件型
4. 像是票價、年齡、性別等，某些因素可能具有較大影響生存率的可能，因此藉由分析不同特徵
   的分部或關聯圖可能使生存率大為提升。

# %%
#HW3
-首先必須先定義"提升業績"的標準，並量化它。可以定義當日營業額=乘客數*總花費，並且以前一日之營業額為基準，若隔日
之營業額超過前一日之10%，定為"業績上升"
-接著找出可能和業績相關的資訊，藉由蒐集不同乘客的資料(EX:年齡,性別,職業,人數,乘車地點,花費)建立大量資料庫，
可利用網路表單填寫或是乘客使用APP叫車之紀錄收集乘客資料
-可續收集一個月之營業額紀錄，並分別對年齡,性別,職業,人數,乘車地點,花費作圖比較，觀察其趨勢及關連性
