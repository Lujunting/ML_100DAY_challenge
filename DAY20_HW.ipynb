# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

# 創建 0~1，透過-0.5*2->-1~1
matrix=(np.random.random((10,10))-0.5)*2
plt.figure(figsize=(10,10))
# 使用heapmap
heatmap=sns.heatmap(matrix,cmap=plt.cm.RdYlBu_r,vmin=-1.,vmax=1.,annot=True)

# %%
# 建構矩陣
nrow=1000
nol=3
# matrix=(np.random.random((1000,3))-0.5)*2
matrix=np.random.randn(nrow*nol).reshape((nrow,nol))
# 隨機給予0,1,2三種標籤
indice=np.random.choice([0,1,2], size=nrow)
plot_data=pd.DataFrame(matrix,indice).reset_index()
plot_data
# Out:
#      index         0         1         2
# 0        1  1.890887 -0.545930  0.645222
# 1        2 -2.096955 -0.274375  2.752448
# 2        2 -0.133855 -1.542491  0.054122
# 3        2 -0.937696  0.055658  0.472019
# 4        2  0.429520 -1.266610 -0.979376
# ..     ...       ...       ...       ...
# 995      2 -0.351266 -0.633340 -2.431057
# 996      1 -0.840857  1.738931  1.437406
# 997      1  0.273408  0.238653 -0.396498
# 998      2  0.849133  0.646947 -0.381268
# 999      2 -0.107806 -1.142236  1.123563
#
# [1000 rows x 4 columns]

# %%
# 繪製seaborn 進階heatmap
grid=sns.PairGrid(data=plot_data,diag_sharey=False,
                 hue='index',vars=[x for x in list(plot_data.columns) if x !='index'])

# 設定右上為散布圖，對角線為KDE，左下為density_plot
grid.map_upper(plt.scatter,alpha=0.2)
grid.map_diag(sns.kdeplot)
grid.map_lower(sns.kdeplot,cmap=plt.cm.OrRd_r)
plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:1144: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:1144: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:1144: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)
